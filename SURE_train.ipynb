# %% [markdown]
# In this file, we demonstrate the training and usage of SURE. Before running the example code in this file, please prepare the data according to the process described [here](./prepare_mtx.ipynb).
#
# First, we use the shell to invoke commands to train the SURE model. In the following command:
# - `--data-file` is used to specify the file containing the single-cell transcriptome data. It can be a csv or tsv file, where rows represent cells and columns represent genes. Do not set row names for each row, meaning there is no need to set an index.
# - `--undesired-factor-file` is used to specify the file containing the undesired factor values. Undesired factors can be batch, sample, or any other factors that you wish to remove from the data. Users can set the undesired factors based on their actual problem requirements.
# - `--jit` is used to enable Jax acceleration. It is worth noting that if users want to use this feature, both `--data-file` and `--undesired-factor-file` need to be provided. If the user only sets `--data-file` and uses `--jit`, the program will encounter an error.
# - `-cd` is used to set the number of metacells.
# - `-lr` is the learning rate.
# - `-n` is the number of epochs.
# - `-bs` is the batch size.
# - `-zi exact` is used to specify the exact form of the zero-inflated model.
# - `-dirichlet` is used to specify the Dirichlet-multinomial distribution.
# - `-likeli negbinomial` is used to specify the negative binomial distribution model for calculating the data likelihood.

# %%
# %%bash
#
# CUDA_VISIBLE_DEVICES=0  python SURE.py --data-file "/home/oem/SURE_example_1/multiome_neurips21_counts.txt.gz" \
#                         --undesired-factor-file "/home/oem/SURE_example_1/multiome_neurips21_uwv.txt.gz" \
#                         --jit \
#                         -rt \
#                         -cd 500 \
#                         -lr 0.0001 \
#                         -n 300 \
#                         -bs 1000 \
#                         --seed 0 \
#                         --cuda \
#                         -zi exact \
#                         -dirichlet \
#                         -likeli negbinomial \
#                         --save-model "sure_4_neurips21.pth" 2>&1 | tee "sure_4_neurips21.log"
# Out:
# /home/oem/anaconda3/envs/pyro/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 1 epoch: avg losses 2235618.8875 elapsed 16.4599 seconds
# 2 epoch: avg losses 1851323.9920 elapsed 1.9692 seconds
# 3 epoch: avg losses 1727529.5679 elapsed 1.9113 seconds
# 4 epoch: avg losses 1616381.0170 elapsed 1.9556 seconds
# 5 epoch: avg losses 1506066.2089 elapsed 1.9485 seconds
# 6 epoch: avg losses 1427844.9554 elapsed 1.9477 seconds
# 7 epoch: avg losses 1366441.6982 elapsed 1.9086 seconds
# 8 epoch: avg losses 1327284.3955 elapsed 2.0293 seconds
# 9 epoch: avg losses 1298740.6536 elapsed 1.9923 seconds
# 10 epoch: avg losses 1283441.2491 elapsed 2.0349 seconds
# 11 epoch: avg losses 1265902.8804 elapsed 1.9946 seconds
# 12 epoch: avg losses 1247983.9223 elapsed 2.0316 seconds
# 13 epoch: avg losses 1239221.8848 elapsed 2.0276 seconds
# 14 epoch: avg losses 1232591.0964 elapsed 1.9604 seconds
# 15 epoch: avg losses 1227097.6250 elapsed 1.9949 seconds
# 16 epoch: avg losses 1222439.5884 elapsed 2.0462 seconds
# 17 epoch: avg losses 1218316.6545 elapsed 2.0404 seconds
# 18 epoch: avg losses 1214595.8366 elapsed 1.9950 seconds
# 19 epoch: avg losses 1211230.0071 elapsed 2.0146 seconds
# 20 epoch: avg losses 1208192.7786 elapsed 2.0367 seconds
# 21 epoch: avg losses 1205301.5116 elapsed 2.0422 seconds
# 22 epoch: avg losses 1202652.3393 elapsed 1.9854 seconds
# 23 epoch: avg losses 1200307.5304 elapsed 1.9967 seconds
# 24 epoch: avg losses 1198114.1473 elapsed 2.0350 seconds
# 25 epoch: avg losses 1195928.9500 elapsed 2.0385 seconds
# 26 epoch: avg losses 1193870.5125 elapsed 1.9749 seconds
# 27 epoch: avg losses 1191786.0777 elapsed 1.9570 seconds
# 28 epoch: avg losses 1189860.2598 elapsed 1.9969 seconds
# 29 epoch: avg losses 1187902.0080 elapsed 1.9982 seconds
# 30 epoch: avg losses 1186046.4321 elapsed 1.9702 seconds
# 31 epoch: avg losses 1184174.6009 elapsed 1.9660 seconds
# 32 epoch: avg losses 1182307.5545 elapsed 1.9972 seconds
# 33 epoch: avg losses 1180532.7589 elapsed 1.9938 seconds
# 34 epoch: avg losses 1178762.4598 elapsed 1.9511 seconds
# 35 epoch: avg losses 1177003.6420 elapsed 2.0014 seconds
# 36 epoch: avg losses 1175277.1920 elapsed 2.0359 seconds
# 37 epoch: avg losses 1173571.5884 elapsed 2.0125 seconds
# 38 epoch: avg losses 1171911.0634 elapsed 1.9575 seconds
# 39 epoch: avg losses 1170207.8723 elapsed 1.9692 seconds
# 40 epoch: avg losses 1168603.5750 elapsed 1.9962 seconds
# 41 epoch: avg losses 1166989.8473 elapsed 1.9828 seconds
# 42 epoch: avg losses 1165314.6313 elapsed 1.9471 seconds
# 43 epoch: avg losses 1163838.0259 elapsed 1.9459 seconds
# 44 epoch: avg losses 1162418.6741 elapsed 1.9860 seconds
# 45 epoch: avg losses 1160956.0866 elapsed 1.9886 seconds
# 46 epoch: avg losses 1159524.8687 elapsed 1.9484 seconds
# 47 epoch: avg losses 1158107.7304 elapsed 1.9528 seconds
# 48 epoch: avg losses 1156652.1071 elapsed 1.9851 seconds
# 49 epoch: avg losses 1155255.2393 elapsed 1.9818 seconds
# 50 epoch: avg losses 1153781.0518 elapsed 1.9460 seconds
# 51 epoch: avg losses 1152419.1000 elapsed 1.9454 seconds
# 52 epoch: avg losses 1150995.7411 elapsed 1.9873 seconds
# 53 epoch: avg losses 1149596.1455 elapsed 1.9858 seconds
# 54 epoch: avg losses 1148246.1848 elapsed 1.9444 seconds
# 55 epoch: avg losses 1146893.3687 elapsed 1.9452 seconds
# 56 epoch: avg losses 1145512.5634 elapsed 1.9855 seconds
# 57 epoch: avg losses 1144125.9241 elapsed 1.9890 seconds
# 58 epoch: avg losses 1142825.5063 elapsed 1.9458 seconds
# 59 epoch: avg losses 1141414.5491 elapsed 1.9452 seconds
# 60 epoch: avg losses 1140109.8920 elapsed 1.9850 seconds
# 61 epoch: avg losses 1138682.2411 elapsed 1.9843 seconds
# 62 epoch: avg losses 1137402.5188 elapsed 1.9464 seconds
# 63 epoch: avg losses 1136191.8080 elapsed 1.9491 seconds
# 64 epoch: avg losses 1134988.9223 elapsed 1.9830 seconds
# 65 epoch: avg losses 1133757.6482 elapsed 1.9891 seconds
# 66 epoch: avg losses 1132614.8000 elapsed 1.9458 seconds
# 67 epoch: avg losses 1131423.2884 elapsed 1.9472 seconds
# 68 epoch: avg losses 1130203.1875 elapsed 1.9857 seconds
# 69 epoch: avg losses 1129027.4875 elapsed 1.9847 seconds
# 70 epoch: avg losses 1127840.2661 elapsed 1.9449 seconds
# 71 epoch: avg losses 1126654.3420 elapsed 1.9459 seconds
# 72 epoch: avg losses 1125519.1232 elapsed 1.9839 seconds
# 73 epoch: avg losses 1124390.1848 elapsed 1.9825 seconds
# 74 epoch: avg losses 1123214.2348 elapsed 1.9439 seconds
# 75 epoch: avg losses 1121963.8518 elapsed 1.9458 seconds
# 76 epoch: avg losses 1120789.2170 elapsed 1.9846 seconds
# 77 epoch: avg losses 1119666.7786 elapsed 1.9849 seconds
# 78 epoch: avg losses 1118525.9116 elapsed 1.9977 seconds
# 79 epoch: avg losses 1117370.6446 elapsed 1.9552 seconds
# 80 epoch: avg losses 1116188.0411 elapsed 1.9884 seconds
# 81 epoch: avg losses 1115100.9054 elapsed 1.9846 seconds
# 82 epoch: avg losses 1113969.2080 elapsed 1.9466 seconds
# 83 epoch: avg losses 1112917.9536 elapsed 1.9471 seconds
# 84 epoch: avg losses 1111851.2134 elapsed 1.9848 seconds
# 85 epoch: avg losses 1110762.4232 elapsed 1.9849 seconds
# 86 epoch: avg losses 1109822.6830 elapsed 1.9699 seconds
# 87 epoch: avg losses 1108775.3527 elapsed 1.9523 seconds
# 88 epoch: avg losses 1107794.3080 elapsed 1.9865 seconds
# 89 epoch: avg losses 1106792.8848 elapsed 1.9859 seconds
# 90 epoch: avg losses 1105743.5312 elapsed 1.9459 seconds
# 91 epoch: avg losses 1104691.1330 elapsed 1.9471 seconds
# 92 epoch: avg losses 1103709.9295 elapsed 1.9856 seconds
# 93 epoch: avg losses 1102681.8661 elapsed 1.9842 seconds
# 94 epoch: avg losses 1101658.1786 elapsed 1.9448 seconds
# 95 epoch: avg losses 1100689.0938 elapsed 1.9449 seconds
# 96 epoch: avg losses 1099636.9330 elapsed 1.9830 seconds
# 97 epoch: avg losses 1098642.8804 elapsed 1.9868 seconds
# 98 epoch: avg losses 1097615.7920 elapsed 1.9439 seconds
# 99 epoch: avg losses 1096601.2955 elapsed 1.9434 seconds
# 100 epoch: avg losses 1095605.4214 elapsed 1.9886 seconds
# 101 epoch: avg losses 1094627.3741 elapsed 1.9871 seconds
# 102 epoch: avg losses 1093641.9652 elapsed 1.9454 seconds
# 103 epoch: avg losses 1092707.7580 elapsed 1.9460 seconds
# 104 epoch: avg losses 1091789.4268 elapsed 1.9848 seconds
# 105 epoch: avg losses 1090879.5554 elapsed 1.9893 seconds
# 106 epoch: avg losses 1089951.7973 elapsed 1.9460 seconds
# 107 epoch: avg losses 1089109.6911 elapsed 1.9567 seconds
# 108 epoch: avg losses 1088181.3920 elapsed 1.9857 seconds
# 109 epoch: avg losses 1087258.3250 elapsed 1.9858 seconds
# 110 epoch: avg losses 1086427.7241 elapsed 1.9484 seconds
# 111 epoch: avg losses 1085507.6420 elapsed 1.9453 seconds
# 112 epoch: avg losses 1084570.4768 elapsed 1.9856 seconds
# 113 epoch: avg losses 1083673.0973 elapsed 1.9945 seconds
# 114 epoch: avg losses 1082770.4598 elapsed 1.9462 seconds
# 115 epoch: avg losses 1081969.8393 elapsed 1.9449 seconds
# 116 epoch: avg losses 1080989.8661 elapsed 1.9851 seconds
# 117 epoch: avg losses 1080137.8714 elapsed 1.9864 seconds
# 118 epoch: avg losses 1079268.4598 elapsed 1.9481 seconds
# 119 epoch: avg losses 1078347.8313 elapsed 1.9460 seconds
# 120 epoch: avg losses 1077446.6625 elapsed 1.9843 seconds
# 121 epoch: avg losses 1076583.2241 elapsed 1.9838 seconds
# 122 epoch: avg losses 1075656.1643 elapsed 1.9458 seconds
# 123 epoch: avg losses 1074823.8777 elapsed 1.9447 seconds
# 124 epoch: avg losses 1074049.2339 elapsed 1.9871 seconds
# 125 epoch: avg losses 1073305.0357 elapsed 1.9949 seconds
# 126 epoch: avg losses 1072484.2705 elapsed 1.9567 seconds
# 127 epoch: avg losses 1071637.5375 elapsed 1.9529 seconds
# 128 epoch: avg losses 1070826.2964 elapsed 1.9969 seconds
# 129 epoch: avg losses 1070039.5580 elapsed 1.9940 seconds
# 130 epoch: avg losses 1069216.1679 elapsed 1.9553 seconds
# 131 epoch: avg losses 1068453.6018 elapsed 1.9559 seconds
# 132 epoch: avg losses 1067612.8062 elapsed 1.9948 seconds
# 133 epoch: avg losses 1066832.6705 elapsed 2.0101 seconds
# 134 epoch: avg losses 1066022.7357 elapsed 1.9603 seconds
# 135 epoch: avg losses 1065264.8902 elapsed 1.9698 seconds
# 136 epoch: avg losses 1064456.2080 elapsed 2.0010 seconds
# 137 epoch: avg losses 1063655.3848 elapsed 2.0210 seconds
# 138 epoch: avg losses 1062856.9045 elapsed 1.9719 seconds
# 139 epoch: avg losses 1062074.9089 elapsed 1.9651 seconds
# 140 epoch: avg losses 1061246.0821 elapsed 2.0068 seconds
# 141 epoch: avg losses 1060474.3062 elapsed 2.0104 seconds
# 142 epoch: avg losses 1059656.1062 elapsed 1.9674 seconds
# 143 epoch: avg losses 1058955.0714 elapsed 1.9610 seconds
# 144 epoch: avg losses 1058211.5205 elapsed 2.0079 seconds
# 145 epoch: avg losses 1057499.5125 elapsed 2.0109 seconds
# 146 epoch: avg losses 1056806.7348 elapsed 1.9656 seconds
# 147 epoch: avg losses 1056059.6000 elapsed 1.9650 seconds
# 148 epoch: avg losses 1055350.3598 elapsed 2.0081 seconds
# 149 epoch: avg losses 1054652.8357 elapsed 2.0069 seconds
# 150 epoch: avg losses 1053937.8848 elapsed 1.9608 seconds
# 151 epoch: avg losses 1053242.4937 elapsed 1.9621 seconds
# 152 epoch: avg losses 1052461.5134 elapsed 1.9999 seconds
# 153 epoch: avg losses 1051784.8670 elapsed 2.0029 seconds
# 154 epoch: avg losses 1051059.5429 elapsed 1.9687 seconds
# 155 epoch: avg losses 1050366.5562 elapsed 1.9666 seconds
# 156 epoch: avg losses 1049653.5991 elapsed 2.0071 seconds
# 157 epoch: avg losses 1048903.3482 elapsed 2.0054 seconds
# 158 epoch: avg losses 1048209.8714 elapsed 1.9648 seconds
# 159 epoch: avg losses 1047461.4357 elapsed 1.9700 seconds
# 160 epoch: avg losses 1046757.5732 elapsed 2.0029 seconds
# 161 epoch: avg losses 1046056.4250 elapsed 2.0111 seconds
# 162 epoch: avg losses 1045347.0000 elapsed 1.9645 seconds
# 163 epoch: avg losses 1044678.9777 elapsed 1.9656 seconds
# 164 epoch: avg losses 1044106.7518 elapsed 2.0029 seconds
# 165 epoch: avg losses 1043444.6920 elapsed 2.0024 seconds
# 166 epoch: avg losses 1042754.4580 elapsed 1.9633 seconds
# 167 epoch: avg losses 1042150.8946 elapsed 1.9624 seconds
# 168 epoch: avg losses 1041503.8714 elapsed 1.9990 seconds
# 169 epoch: avg losses 1040839.7116 elapsed 2.0078 seconds
# 170 epoch: avg losses 1040184.1188 elapsed 1.9736 seconds
# 171 epoch: avg losses 1039589.4509 elapsed 1.9625 seconds
# 172 epoch: avg losses 1038924.2446 elapsed 1.9996 seconds
# 173 epoch: avg losses 1038297.4259 elapsed 2.0110 seconds
# 174 epoch: avg losses 1037593.1634 elapsed 1.9533 seconds
# 175 epoch: avg losses 1037047.8143 elapsed 1.9568 seconds
# 176 epoch: avg losses 1036350.1964 elapsed 2.0084 seconds
# 177 epoch: avg losses 1035685.4286 elapsed 1.9935 seconds
# 178 epoch: avg losses 1035066.1241 elapsed 1.9540 seconds
# 179 epoch: avg losses 1034420.5116 elapsed 1.9522 seconds
# 180 epoch: avg losses 1033795.0670 elapsed 2.0018 seconds
# 181 epoch: avg losses 1033183.6607 elapsed 2.0199 seconds
# 182 epoch: avg losses 1032517.5714 elapsed 1.9641 seconds
# 183 epoch: avg losses 1031926.5402 elapsed 1.9532 seconds
# 184 epoch: avg losses 1031350.8027 elapsed 1.9977 seconds
# 185 epoch: avg losses 1030764.9348 elapsed 1.9945 seconds
# 186 epoch: avg losses 1030223.9527 elapsed 1.9817 seconds
# 187 epoch: avg losses 1029652.9929 elapsed 1.9659 seconds
# 188 epoch: avg losses 1029090.9777 elapsed 2.0058 seconds
# 189 epoch: avg losses 1028472.1304 elapsed 2.0066 seconds
# 190 epoch: avg losses 1027882.6545 elapsed 1.9681 seconds
# 191 epoch: avg losses 1027286.1929 elapsed 1.9541 seconds
# 192 epoch: avg losses 1026723.7625 elapsed 1.9961 seconds
# 193 epoch: avg losses 1026136.3768 elapsed 1.9965 seconds
# 194 epoch: avg losses 1025599.4250 elapsed 1.9569 seconds
# 195 epoch: avg losses 1024999.9482 elapsed 1.9515 seconds
# 196 epoch: avg losses 1024403.6402 elapsed 1.9924 seconds
# 197 epoch: avg losses 1023822.6429 elapsed 1.9934 seconds
# 198 epoch: avg losses 1023280.8848 elapsed 1.9577 seconds
# 199 epoch: avg losses 1022726.6991 elapsed 1.9654 seconds
# 200 epoch: avg losses 1022138.5777 elapsed 1.9942 seconds
# 201 epoch: avg losses 1021595.1196 elapsed 2.0001 seconds
# 202 epoch: avg losses 1021012.4393 elapsed 1.9618 seconds
# 203 epoch: avg losses 1020450.4875 elapsed 1.9598 seconds
# 204 epoch: avg losses 1019928.3313 elapsed 2.0237 seconds
# 205 epoch: avg losses 1019454.0759 elapsed 2.0003 seconds
# 206 epoch: avg losses 1018887.5643 elapsed 1.9536 seconds
# 207 epoch: avg losses 1018368.5929 elapsed 1.9538 seconds
# 208 epoch: avg losses 1017816.8018 elapsed 1.9979 seconds
# 209 epoch: avg losses 1017308.2286 elapsed 1.9971 seconds
# 210 epoch: avg losses 1016824.6259 elapsed 1.9482 seconds
# 211 epoch: avg losses 1016246.1625 elapsed 1.9510 seconds
# 212 epoch: avg losses 1015801.1089 elapsed 1.9912 seconds
# 213 epoch: avg losses 1015256.1232 elapsed 1.9924 seconds
# 214 epoch: avg losses 1014754.7223 elapsed 1.9512 seconds
# 215 epoch: avg losses 1014198.5223 elapsed 1.9521 seconds
# 216 epoch: avg losses 1013717.3375 elapsed 1.9906 seconds
# 217 epoch: avg losses 1013176.6116 elapsed 2.0050 seconds
# 218 epoch: avg losses 1012706.3768 elapsed 2.0063 seconds
# 219 epoch: avg losses 1012166.6866 elapsed 1.9995 seconds
# 220 epoch: avg losses 1011624.6857 elapsed 2.0391 seconds
# 221 epoch: avg losses 1011147.5786 elapsed 2.0380 seconds
# 222 epoch: avg losses 1010578.4232 elapsed 1.9668 seconds
# 223 epoch: avg losses 1010140.6545 elapsed 1.9772 seconds
# 224 epoch: avg losses 1009641.4348 elapsed 2.0498 seconds
# 225 epoch: avg losses 1009160.6152 elapsed 2.0359 seconds
# 226 epoch: avg losses 1008694.1518 elapsed 1.9997 seconds
# 227 epoch: avg losses 1008247.8705 elapsed 1.9989 seconds
# 228 epoch: avg losses 1007736.3643 elapsed 2.0384 seconds
# 229 epoch: avg losses 1007344.3018 elapsed 2.0388 seconds
# 230 epoch: avg losses 1006833.1973 elapsed 1.9970 seconds
# 231 epoch: avg losses 1006376.3482 elapsed 1.9995 seconds
# 232 epoch: avg losses 1005910.2580 elapsed 2.0391 seconds
# 233 epoch: avg losses 1005476.8848 elapsed 2.0378 seconds
# 234 epoch: avg losses 1004941.6554 elapsed 1.9959 seconds
# 235 epoch: avg losses 1004514.7071 elapsed 1.9962 seconds
# 236 epoch: avg losses 1004045.6839 elapsed 2.0427 seconds
# 237 epoch: avg losses 1003577.0687 elapsed 2.0429 seconds
# 238 epoch: avg losses 1003132.7491 elapsed 1.9961 seconds
# 239 epoch: avg losses 1002648.8804 elapsed 1.9952 seconds
# 240 epoch: avg losses 1002194.8134 elapsed 2.0390 seconds
# 241 epoch: avg losses 1001743.6446 elapsed 2.0215 seconds
# 242 epoch: avg losses 1001228.6107 elapsed 1.9566 seconds
# 243 epoch: avg losses 1000785.2518 elapsed 1.9566 seconds
# 244 epoch: avg losses 1000376.3009 elapsed 1.9964 seconds
# 245 epoch: avg losses 999959.9804 elapsed 2.0050 seconds
# 246 epoch: avg losses 999599.2384 elapsed 1.9565 seconds
# 247 epoch: avg losses 999166.1366 elapsed 1.9683 seconds
# 248 epoch: avg losses 998730.6536 elapsed 2.0033 seconds
# 249 epoch: avg losses 998265.4232 elapsed 1.9840 seconds
# 250 epoch: avg losses 997849.5964 elapsed 1.9431 seconds
# 251 epoch: avg losses 997481.2804 elapsed 1.9514 seconds
# 252 epoch: avg losses 997081.3259 elapsed 1.9921 seconds
# 253 epoch: avg losses 996610.4348 elapsed 2.0015 seconds
# 254 epoch: avg losses 996195.6116 elapsed 1.9543 seconds
# 255 epoch: avg losses 995780.7902 elapsed 1.9528 seconds
# 256 epoch: avg losses 995349.7652 elapsed 1.9945 seconds
# 257 epoch: avg losses 994923.0696 elapsed 1.9921 seconds
# 258 epoch: avg losses 994510.2063 elapsed 1.9527 seconds
# 259 epoch: avg losses 994128.3429 elapsed 1.9663 seconds
# 260 epoch: avg losses 993701.1134 elapsed 2.0029 seconds
# 261 epoch: avg losses 993269.7357 elapsed 1.9904 seconds
# 262 epoch: avg losses 992807.9714 elapsed 1.9544 seconds
# 263 epoch: avg losses 992479.2473 elapsed 1.9701 seconds
# 264 epoch: avg losses 992081.4313 elapsed 2.0028 seconds
# 265 epoch: avg losses 991689.3634 elapsed 1.9929 seconds
# 266 epoch: avg losses 991347.2670 elapsed 1.9522 seconds
# 267 epoch: avg losses 990959.0768 elapsed 1.9527 seconds
# 268 epoch: avg losses 990574.8196 elapsed 1.9923 seconds
# 269 epoch: avg losses 990171.8143 elapsed 2.0053 seconds
# 270 epoch: avg losses 989793.1232 elapsed 1.9534 seconds
# 271 epoch: avg losses 989401.2411 elapsed 1.9538 seconds
# 272 epoch: avg losses 989032.6705 elapsed 1.9903 seconds
# 273 epoch: avg losses 988700.2482 elapsed 1.9954 seconds
# 274 epoch: avg losses 988372.1438 elapsed 1.9510 seconds
# 275 epoch: avg losses 987943.8071 elapsed 1.9533 seconds
# 276 epoch: avg losses 987555.2598 elapsed 1.9988 seconds
# 277 epoch: avg losses 987221.0304 elapsed 2.0018 seconds
# 278 epoch: avg losses 986809.9375 elapsed 1.9580 seconds
# 279 epoch: avg losses 986445.8554 elapsed 1.9611 seconds
# 280 epoch: avg losses 986056.2411 elapsed 1.9986 seconds
# 281 epoch: avg losses 985696.0036 elapsed 1.9987 seconds
# 282 epoch: avg losses 985268.5259 elapsed 1.9617 seconds
# 283 epoch: avg losses 984948.3107 elapsed 1.9504 seconds
# 284 epoch: avg losses 984613.7089 elapsed 1.9970 seconds
# 285 epoch: avg losses 984281.4375 elapsed 1.9967 seconds
# 286 epoch: avg losses 983923.4777 elapsed 1.9567 seconds
# 287 epoch: avg losses 983577.9009 elapsed 1.9578 seconds
# 288 epoch: avg losses 983285.1330 elapsed 1.9969 seconds
# 289 epoch: avg losses 982900.9152 elapsed 1.9981 seconds
# 290 epoch: avg losses 982569.0982 elapsed 1.9544 seconds
# 291 epoch: avg losses 982280.2598 elapsed 1.9511 seconds
# 292 epoch: avg losses 981922.4116 elapsed 1.9906 seconds
# 293 epoch: avg losses 981561.0598 elapsed 2.0075 seconds
# 294 epoch: avg losses 981211.7598 elapsed 1.9543 seconds
# 295 epoch: avg losses 980888.6107 elapsed 1.9585 seconds
# 296 epoch: avg losses 980554.1607 elapsed 2.0064 seconds
# 297 epoch: avg losses 980202.2277 elapsed 1.9984 seconds
# 298 epoch: avg losses 979890.5598 elapsed 1.9530 seconds
# 299 epoch: avg losses 979537.5723 elapsed 1.9539 seconds
# 300 epoch: avg losses 979168.6955 elapsed 1.9958 seconds
# running time: 608.7760503292084 secs

# %% [markdown]
# Set up the Python environment and load some necessary packages.
#
# Here, we use R for plotting, so we need to use [rpy2](https://rpy2.github.io/). If users want to try running these R code snippets, they need to install these Python packages. If there is no need to run these R code snippets, please ignore them directly.

# %%
import numpy as np
import pandas as pd

from SURE import SURE
from utils.scdata_cached import setup_data_loader, SingleCellCached

import torch
from torch.utils.data import DataLoader

import datatable as dt


# R interface
from rpy2.robjects import pandas2ri
from rpy2.robjects import r
import rpy2.rinterface_lib.callbacks

pandas2ri.activate()

# %load_ext rpy2.ipython
# Out:
# /home/oem/anaconda3/envs/pyro/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
ModelPath = 'sure_4_neurips21.pth'
DataPath='/home/oem/SURE_example_1/multiome_neurips21_counts.txt.gz'

# %%
# load model
model = torch.load(ModelPath)

batch_size = 10000

use_float64 = False
use_cuda = True
log_trans = False

# %%
# load data
data_cached = SingleCellCached(DataPath, None, log_trans=log_trans, use_cuda=False, use_float64 = use_float64)
data_loader = DataLoader(data_cached, batch_size = batch_size, shuffle = False)

# %% [markdown]
# #### Get the latent representations of cells

# %%
embeds = []
weights = []

for xs1,ks2 in data_loader:
    if use_cuda:
        xs1 = xs1.cuda()

    zs = model.get_cell_coordinates(xs1)
    ws = model.soft_assignments(xs1)
    
    if use_cuda:
        zs = zs.cpu().detach().numpy()
        ws = ws.cpu().detach().numpy()
    else:
        zs = zs.detach().numpy()
        ws = ws.detach().numpy()

    embeds.append(zs)
    weights.append(ws)

embeds = np.concatenate(embeds, axis=0)
weights = np.concatenate(weights, axis=0)


cells = pd.read_csv('/home/oem/SURE_example_1/multiome_neurips21_cell.csv.gz', header=0)
genes = pd.read_csv('/home/oem/SURE_example_1/multiome_neurips21_gene.csv.gz', header=0)

df = pd.DataFrame(embeds, index=cells.iloc[:,0].values).reset_index()
dt.Frame(df).to_csv('/home/oem/SURE_example_1/multiome_neurips21_embeds.csv.gz')

df=pd.DataFrame(weights, index=cells.iloc[:,0].values)
dt.Frame(df.reset_index()).to_csv('/home/oem/SURE_example_1/multiome_neurips21_weights.csv.gz')

# %% [markdown]
# #### Get the latent representations of metacells

# %%
codebook=model.get_metacell_coordinates().cpu().detach().numpy()
pd.DataFrame(codebook).to_csv('/home/oem/SURE_example_1/multiome_neurips21_codebook.csv.gz')

# %% [markdown]
# #### Load H5AD files

# %%
import scanpy as sc

adata = sc.read_h5ad('/home/oem/SURE_example_1/GSE194122_openproblems_neurips2021_multiome_BMMC_processed.h5ad')
meta = adata.obs

# %% [markdown]
# #### Invoke R to plot and display the latent representations of cells and metacells.

# %%
# %%R -i meta
#
# library(Seurat)
# library(dplyr)
# library(useful)
# library(data.table)
# library(ggplot2)
# library(cowplot)
# library(uwot)
#
# set.seed(123)
#
# scp <- fread('/home/oem/SURE_example_1/multiome_neurips21_embeds.csv.gz', data.table = FALSE, header = TRUE)
# rownames(scp) <- scp[,1]
# scp <- scp[,-1]
#
# embed.list <- umap(scp, n_threads = 40, pca=NULL, ret_model = TRUE)
# embed <- embed.list$embedding
# colnames(embed) <- c('UMAP_1','UMAP_2')
#
#
#
# recon <- CreateSeuratObject(scp[,1:5] %>% as.matrix %>% t, meta.data = meta[rownames(scp),])
# recon[['umap']] <- CreateDimReducObject(embed %>% as.matrix(), key = 'UMAP_')
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# Loading required package: SeuratObject
# Loading required package: sp
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.5; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
# Attaching package: ‘SeuratObject’
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: ggplot2
# data.table 1.14.10 using 6 threads (see ?getDTthreads).  Latest news: r-datatable.com
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# Loading required package: Matrix
# Warning: Data is of class matrix. Coercing to dgCMatrix.
# In addition: Warning messages:
# 1: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   libraries ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ contain no packages
# 2: No assay specified, setting assay as RNA by default.

# %%
# %%R
#
# codebook <- read.csv('/home/oem/SURE_example_1/multiome_neurips21_codebook.csv.gz', row.names = 1)
# embed_cb <- umap_transform(codebook, embed.list) %>% as.data.frame()
# colnames(embed_cb) <- c('UMAP_1','UMAP_2')

# %%
# %%R -w 800 -h 500 -u px
#
# plt <- DimPlot(recon, reduction = 'umap', group.by = 'cell_type', label=TRUE, repel=TRUE)
# plt + geom_point(data = embed_cb, aes(UMAP_1,UMAP_2), size=1)
